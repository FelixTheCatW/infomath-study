# %% [markdown]
# # Занятие 1. Введение в математику для AI и анализа данных
#
# ## Цель занятия
#
# На этом занятии студенты начинают изучать математическую основу для:
#
# - анализа данных;
# - машинного обучения;
# - искусственного интеллекта;
# - визуализации данных.
#
# Сначала изучите solved-ноутбук вместе с преподавателем. Затем выполните TODO-ноутбук самостоятельно.
#
# Главная задача занятия:
# понять, что такое функция и как выглядят графики функций.
#
# ---
#
# # Почему математика важна для AI
#
# Практически все алгоритмы машинного обучения используют математику:
#
# - функции;
# - графики;
# - оптимизацию;
# - производные;
# - вероятности;
# - статистику.
#
# Например:
#
# - нейросеть — это математическая функция;
# - график показывает зависимость данных;
# - оптимизация помогает модели обучаться.
#
# ---
#
# # Что такое функция
#
# Функция — это правило, которое каждому значению x ставит в соответствие значение y.
#
# Пример:
#
# ```python
# y = 2 * x + 1
# ```
#
# Если:
#
# ```python
# x = 1
# ```
#
# то:
#
# ```python
# y = 3
# ```
#
# ---
#
# # Где функции используются в реальной жизни
#
# Функции используются:
#
# - в прогнозировании цен;
# - в анализе продаж;
# - в спортивной аналитике;
# - в рекомендательных системах;
# - в компьютерном зрении;
# - в нейросетях.
#
# ---
#
# # Что будем изучать сегодня
#
# Сегодня изучаем:
#
# - линейные функции;
# - квадратичные функции;
# - графики;
# - влияние коэффициентов на график;
# - построение графиков через matplotlib.
#
# ---
#
# # Связь с дипломом
#
# В дипломном проекте графики пригодятся для:
#
# - аналитики;
# - визуализации;
# - отчётов;
# - отображения статистики;
# - анализа данных.
#
# ---
#
# # Связь с GitHub
#
# На этом занятии студент должен сохранить:
#
# - solved-ноутбук;
# - TODO-ноутбук;
# - графики;
# - свой commit в GitHub.
#
# Рекомендуемая ветка:
#
# ```bash
# git checkout main
# git pull origin main
# git checkout -b feature/block3-lesson01-functions
# ```
#
# Commit:
#
# ```bash
# git add .
# git commit -m "feat: add math functions lesson"
# git push -u origin feature/block3-lesson01-functions
# ```

# %% [markdown]
# ## Ячейка 1. TODO: импортируйте библиотеки
#
# Подключите:
# - numpy;
# - matplotlib.pyplot.

# %%
# TODO: импортируйте numpy как np
import numpy as np
import matplotlib.pyplot as plt

print("Библиотеки импортированы")
# Out:
# Библиотеки импортированы

# %% [markdown]
# ## Ячейка 2. TODO: создайте линейную функцию
#
# Создайте:
# - массив x;
# - линейную функцию y = 2x + 1.

# %%
x = np.array(range(-5, 5, 2))

y = 2 * x + 1

print("x:", x)
print("y:", y)
# TODO: assert
# Out:
# x: [-5 -3 -1  1  3]
# y: [-9 -5 -1  3  7]

# %% [markdown]
# ## Ячейка 3. TODO: постройте график линейной функции
#
# Постройте график:
#
# ```python
# y = 2x + 1
# ```

# %%
x = np.linspace(-10, 10, 100)

y = 2 * x + 1

plt.figure(figsize=(8, 5))
plt.plot(x, y)

plt.title("Линейная функция y = 2x + 1")
plt.xlabel("x")
plt.ylabel("x")

plt.grid(True)

plt.show()

# %% [markdown]
# ## Ячейка 4. TODO: сравните несколько линейных функций
#
# Постройте:
# - y = x
# - y = 2x
# - y = -x

# %%
x = np.linspace(-10, 10, 100)

y1 = x
y2 = 3 * x
y3 = -x

plt.figure(figsize=(8, 5))

plt.plot(x, y1, label="y = x")
plt.plot(x, y2, label="y = 3x")
plt.plot(x, y3, label="y = -x")

plt.legend()
plt.grid(True)

plt.title("Влияние коэффициента k")

plt.show()

# %% [markdown]
# ## Ячейка 5. TODO: исследуйте коэффициент b
#
# Постройте:
# - y = x
# - y = x + 5
# - y = x - 5

# %%
x = np.linspace(-10, 10, 100)

y1 = x
y2 = 3 * x
y3 = -x

plt.figure(figsize=(8, 5))

plt.plot(x, y1, label="y = x")
plt.plot(x, y2, label="y = 3x")
plt.plot(x, y3, label="y = -x")

plt.legend()
plt.grid(True)

plt.title("Влияние слагаемого")

plt.show()

# %% [markdown]
# ## Ячейка 6. TODO: создайте квадратичную функцию
#
# Постройте график:
#
# ```python
# y = x²
# ```

# %%
x = np.linspace(-10, 10, 100)

y = x ** 2

plt.figure(figsize=(8, 5))

plt.plot(x, y)

plt.title("Квадратичная функция y = x²")
plt.legend()
plt.grid(True)

plt.show()
# Out:
# C:\Temp\ipykernel_23960\3790228996.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ## Ячейка 7. TODO: измените квадратичную функцию
#
# Сравните:
# - y = x²
# - y = 2x²
# - y = x² + 10

# %%
x = np.linspace(-10, 10, 100)
y1  = x ** 2
y2 = 2 * x ** 2
y3 = x ** 2 + 10

plt.figure(figsize=(8, 5))

plt.plot(x, y1, label="y = x²")
plt.plot(x, y2, label="y = 2x²")
plt.plot(x, y3, label="y = x² + 10")

plt.legend()
plt.grid(True)

plt.title("Изменение квадратичной функции")

plt.show()

# %% [markdown]
# ## Ячейка 8. TODO: найдите минимум и максимум
#
# Используйте:
# - np.min()
# - np.max()

# %%
x = np.linspace(-5, 5, 100)

y = x ** 2

print("Минимум:", np.min(y))
print("Максимум:", np.max(y))

assert np.min(y) >= 0
# Out:
# Минимум: 0.002550760126517668
# Максимум: 25.0

# %% [markdown]
# ## Ячейка 9. TODO: постройте график обучения модели
#
# Создайте словарь:
# - epoch
# - loss
#
# И постройте график.

# %%
metrics = {"epoch": [1, 2, 3, 4, 5], "loss": [0.9, 0.7, 0.5, 0.4, 0.3]}

plt.figure(figsize=(8, 5))

plt.plot(metrics["epoch"], metrics["loss"])

plt.title("Пример графика обучения модели")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.grid(True)
plt.show()

assert len(metrics["epoch"]) == 5

# %% [markdown]
# ## Ячейка 10. TODO: сделайте выводы по занятию
#
# Создайте список из 4 выводов по теме функций и графиков.

# %%
summary = [
    "Функции используются в AI",
    "Графики помогают анализировать данные",
    "matplotlib используется для визуализации",
    "Линейные и квадратичные функции — основа дальнейшей математики",
]

for item in summary:
    print("-", item)

assert len(summary) == 4
# Out:
# - Функции используются в AI
# - Графики помогают анализировать данные
# - matplotlib используется для визуализации
# - Линейные и квадратичные функции — основа дальнейшей математики
