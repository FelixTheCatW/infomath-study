# %% [markdown]
# # Блок 3. Продвинутый уровень. Занятие 16
#
# ## Финальный мини-проект по анализу данных
#
# ### Цель занятия
#
# Это финальное занятие продвинутого блока по математике, информатике и анализу данных.
#
# Сначала изучите SOLVED-ноутбук вместе с преподавателем. Затем выберите один из трёх датасетов и выполните TODO самостоятельно.
#
# Студент выбирает один из трёх датасетов:
#
# 1. Питание.
# 2. Недвижимость.
# 3. Финансы.
#
# И выполняет полный цикл анализа:
#
# ```text
# загрузка → исследование → очистка → визуализация → зависимости → оптимизация → прогноз → выводы → GitHub
# ```
#
# ---
#
# ## Вариант 1. Датасет по питанию
#
# Используем открытый датасет заказов Chipotle:
#
# ```text
# https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv
# ```
#
# ### Колонки на русском языке
#
# | Колонка | Описание |
# |---|---|
# | order_id | номер заказа |
# | quantity | количество позиций |
# | item_name | название блюда |
# | choice_description | описание выбора / добавок |
# | item_price | цена позиции |
#
# ### Что можно анализировать
#
# - самые популярные блюда;
# - средний чек;
# - максимальную цену позиции;
# - зависимость суммы от количества;
# - TOP блюд по выручке.
#
# ---
#
# ## Вариант 2. Датасет по недвижимости
#
# Используем California Housing:
#
# ```text
# https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.csv
# ```
#
# ### Колонки на русском языке
#
# | Колонка | Описание |
# |---|---|
# | longitude | долгота района |
# | latitude | широта района |
# | housing_median_age | медианный возраст домов |
# | total_rooms | общее количество комнат |
# | total_bedrooms | общее количество спален |
# | population | население района |
# | households | количество домохозяйств |
# | median_income | медианный доход |
# | median_house_value | медианная стоимость жилья |
# | ocean_proximity | близость к океану |
#
# ### Что можно анализировать
#
# - зависимость цены жилья от дохода;
# - максимальную и минимальную стоимость;
# - корреляции признаков;
# - приближённую производную;
# - простой прогноз цены.
#
# ---
#
# ## Вариант 3. Финансовый датасет
#
# Используем S&P500:
#
# ```text
# https://raw.githubusercontent.com/datasets/s-and-p-500/master/data/data.csv
# ```
#
# ### Колонки на русском языке
#
# | Колонка | Описание |
# |---|---|
# | Date | дата наблюдения |
# | SP500 | значение индекса S&P500 |
#
# ### Что можно анализировать
#
# - динамику индекса;
# - изменение индекса;
# - скользящее среднее;
# - минимум и максимум;
# - простой прогноз.
#
# ---
#
# ## Прикладное значение
#
# Такой мини-проект показывает, что студент умеет:
#
# - работать с реальными данными;
# - понимать смысл колонок;
# - строить графики;
# - искать зависимости;
# - находить оптимальные значения;
# - делать простейший прогноз;
# - формировать аналитический отчёт.
#
# ---
#
# ## Связь с дипломом
#
# Этот ноутбук можно использовать как основу для дипломного проекта.
#
# Студент может заменить датасет на свой и сохранить логику:
#
# 1. Загрузка.
# 2. Исследование.
# 3. Анализ.
# 4. Визуализация.
# 5. Выводы.
# 6. GitHub.
#
# ---
#
# ## GitHub
#
# ```bash
# git checkout main
# git pull origin main
# git checkout -b feature/math-advanced-final-project
#
# git add .
# git commit -m "feat: add advanced math final data project"
# git push -u origin feature/math-advanced-final-project
# ```

# %% [markdown]
# ## Ячейка 1. TODO: импорт библиотек
#
# ### Алгоритм
#
# 1. Импортируйте `pandas`.
# 2. Импортируйте `numpy`.
# 3. Импортируйте `matplotlib.pyplot`.
# 4. Добавьте проверки.

# %%
datasets = {
    "food": {
        "name": "Питание / заказы Chipotle",
        "url": "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv",
        "separator": "\t",
    },
    "real_estate": {
        "name": "Недвижимость / California Housing",
        "url": "https://raw.githubusercontent.com/ageron/handson-ml/master/datasets/housing/housing.csv",
        "separator": ",",
    },
    "finance": {
        "name": "Финансы / S&P500",
        "url": "https://raw.githubusercontent.com/datasets/s-and-p-500/master/data/data.csv",
        "separator": ",",
    },
}

dataset_choice = "food"

selected_dataset = datasets[dataset_choice]

print("Выбранный датасет:", selected_dataset["name"])
print("URL:", selected_dataset["url"])

assert dataset_choice in datasets
# Out:
# Выбранный датасет: Питание / заказы Chipotle
# URL: https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv

# %% [markdown]
# ## Ячейка 2. TODO: выбор датасета
#
# ### Алгоритм
#
# 1. Создайте словарь `datasets`.
# 2. Добавьте 3 варианта: food, real_estate, finance.
# 3. Выберите один вариант через `dataset_choice`.
# 4. Проверьте, что выбранный ключ есть в словаре.

# %%
# TODO: создайте словарь datasets

# TODO: выберите dataset_choice

# TODO: создайте selected_dataset

# TODO: выведите название и URL

# TODO: assert dataset_choice in datasets

# %% [markdown]
# ## Ячейка 3. TODO: загрузка данных
#
# ### Алгоритм
#
# 1. Используйте `pd.read_csv`.
# 2. Учтите разделитель для TSV/CSV.
# 3. Покажите первые строки.
# 4. Проверьте размер таблицы.

# %%
# TODO: загрузите df

# TODO: покажите df.head()

# TODO: выведите df.shape

# TODO: assert len(df) > 0

# %% [markdown]
# ## Ячейка 4. TODO: русское описание колонок
#
# ### Алгоритм
#
# 1. Создайте словарь `column_descriptions`.
# 2. Опишите колонки выбранного датасета на русском.
# 3. Выведите названия колонок и пояснения.

# %%
# TODO: создайте column_descriptions

# TODO: выберите description

# TODO: через for выведите описание колонок

# TODO: assert len(description) >= 2

# %% [markdown]
# ## Ячейка 5. TODO: исследование и очистка
#
# ### Алгоритм
#
# 1. Выведите типы данных.
# 2. Посчитайте пропуски.
# 3. Выполните очистку под выбранный датасет.
# 4. Проверьте, что данные остались.

# %%
# TODO: выведите df.dtypes

# TODO: выведите df.isna().sum()

# TODO: выполните обработку для выбранного dataset_choice

# TODO: assert len(df) > 0

# %% [markdown]
# ## Ячейка 6. TODO: базовая статистика
#
# ### Алгоритм
#
# 1. Выберите числовые колонки.
# 2. Используйте `describe()`.
# 3. Покажите статистику.
# 4. Проверьте, что есть хотя бы одна числовая колонка.

# %%
# TODO: создайте numeric_df

# TODO: создайте stats

# TODO: покажите stats

# TODO: assert numeric_df.shape[1] >= 1

# %% [markdown]
# ## Ячейка 7. TODO: визуализация ключевого показателя
#
# ### Алгоритм
#
# 1. Для выбранного датасета выберите главный показатель.
# 2. Постройте график.
# 3. Добавьте заголовок, подписи и сетку.

# %%
# TODO: создайте figure

# TODO: постройте график в зависимости от dataset_choice

# TODO: добавьте title, labels, grid

# TODO: show()

# TODO: assert

# %% [markdown]
# ## Ячейка 8. TODO: анализ зависимости
#
# ### Алгоритм
#
# 1. Выберите два связанных признака.
# 2. Постройте scatter или line plot.
# 3. Добавьте подписи.
# 4. Сделайте вывод.

# %%
# TODO: постройте график зависимости

# TODO: добавьте title, xlabel, ylabel, grid

# TODO: show()

# TODO: assert

# %% [markdown]
# ## Ячейка 9. TODO: оптимизация и простой прогноз
#
# ### Алгоритм
#
# 1. Найдите максимум.
# 2. Найдите минимум.
# 3. Сделайте простой прогноз.
# 4. Сохраните результат в словарь `optimization_report`.

# %%
# TODO: найдите max_name, max_value

# TODO: найдите min_name, min_value

# TODO: посчитайте forecast

# TODO: создайте optimization_report

# TODO: выведите отчёт

# TODO: assert optimization_report["max_value"] >= optimization_report["min_value"]

# %% [markdown]
# ## Ячейка 10. TODO: итоговый отчёт и GitHub
#
# ### Алгоритм
#
# 1. Создайте `project_report`.
# 2. Добавьте информацию о датасете.
# 3. Добавьте результаты оптимизации.
# 4. Напишите 5 выводов.
# 5. Выведите GitHub-команды.

# %%
# TODO: создайте project_report

# TODO: выведите project_report

# TODO: создайте conclusions из 5 выводов

# TODO: выведите conclusions

# TODO: выведите GitHub-команды

# TODO: assert project_report["rows"] > 0

# TODO: assert len(conclusions) == 5

# %% [markdown]
# # Итог TODO-задания
#
# Покажите преподавателю:
#
# - выбранный датасет;
# - русское описание колонок;
# - очистку данных;
# - статистику;
# - графики;
# - зависимости;
# - максимум и минимум;
# - простой прогноз;
# - итоговые выводы;
# - GitHub-команды.
