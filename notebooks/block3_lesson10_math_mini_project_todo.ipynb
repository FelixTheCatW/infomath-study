# %% [markdown]
# # Занятие 10. Итоговый мини-проект по математике и информатике
#
# ## Цель занятия
#
# Это финальное занятие блока **«Основы математики и информатики»**.
#
# В этом блоке мы изучили:
#
# - функции;
# - графики;
# - элементарные функции;
# - алгоритмы;
# - структуры данных;
# - пределы;
# - непрерывность;
# - производную;
# - правила дифференцирования;
# - оптимизацию функций одной переменной.
#
# Сначала изучите solved-ноутбук вместе с преподавателем. Затем выполните TODO-ноутбук самостоятельно.
#
# Сегодня собираем всё в один понятный мини-проект.
#
# ---
#
# # Главная идея занятия
#
# Мы сделаем учебный мини-проект:
#
# ## Анализ функции ошибки модели
#
# Будем считать, что у нас есть простая функция ошибки:
#
# ```python
# loss(x) = (x - 3)² + 2
# ```
#
# Задача:
#
# - построить график функции;
# - найти минимум;
# - посчитать производную;
# - показать движение к минимуму;
# - сохранить результаты в структуру данных;
# - сделать простой отчёт.
#
# ---
#
# # Зачем это нужно для AI
#
# Машинное обучение — это поиск минимальной ошибки.
#
# Модель обучается так:
#
# 1. считает ошибку;
# 2. смотрит, куда ошибка растёт;
# 3. двигается в обратную сторону;
# 4. постепенно приближается к минимуму.
#
# Это основа градиентного спуска.
#
# ---
#
# # Зачем это нужно в реальной жизни
#
# Оптимизация используется в разных задачах:
#
# - уменьшить ошибку прогноза;
# - подобрать лучший режим тренировки;
# - снизить расходы;
# - увеличить прибыль;
# - найти лучший score модели;
# - выбрать оптимальные параметры.
#
# ---
#
# # Зачем это нужно в дипломе
#
# В дипломном проекте студент сможет объяснить:
#
# - что такое функция ошибки;
# - почему важно искать минимум;
# - как графики помогают анализировать модель;
# - как Python помогает визуализировать математику;
# - как связаны математика, информатика и AI.
#
# ---
#
# # Связь с GitHub
#
# На занятии студент сохраняет:
#
# - solved-ноутбук;
# - TODO-ноутбук;
# - графики;
# - итоговый отчёт;
# - commit в GitHub.
#
# Рекомендуемая ветка:
#
# ```bash
# git checkout main
# git pull origin main
# git checkout -b feature/block3-lesson10-math-mini-project
# ```
#
# Commit:
#
# ```bash
# git add .
# git commit -m "feat: add math informatics mini project"
# git push -u origin feature/block3-lesson10-math-mini-project
# ```

# %% [markdown]
# ## Ячейка 1. TODO: импортируйте библиотеки

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("Библиотеки подключены")
# Out:
# Библиотеки подключены

# %% [markdown]
# ## Ячейка 2. TODO: создайте функцию ошибки
#
# Используйте функцию:
#
# ```python
# loss(x) = (x - 4)² + 1
# ```
#
# Минимум находится при `x = 4`, значение минимума равно `1`.

# %%
def loss_function(x):
    return (x - 4) ** 2 + 1


x0 = 4
minimum_value = loss_function(x0)

print("Минимум находится при x =", x0)
print("Минимальное значение loss =", minimum_value)

assert minimum_value == 1
# Out:
# Минимум находится при x = 4
# Минимальное значение loss = 1

# %% [markdown]
# ## Ячейка 3. TODO: постройте график функции ошибки

# %%
# TODO: создайте x через np.linspace()

# TODO: создайте loss = loss_function(x)

# TODO: постройте график

# TODO: отметьте минимум x=4, y=1

# TODO: добавьте title, xlabel, ylabel, legend, grid

# TODO: show()

# TODO: assert

x = np.linspace(-5, 5, 300)
loss = loss_function(x)

plt.figure(figsize=(8, 5))
plt.plot(x, loss, label="loss(x) = (x - 4)² + 1")
plt.scatter([3], [2], label="минимум")

plt.title("Функция ошибки модели")
plt.xlabel("x")
plt.ylabel("loss")
plt.legend()
plt.grid(True)
plt.show()

assert min(loss) >= 1

# %% [markdown]
# ## Ячейка 4. TODO: создайте производную функции ошибки
#
# Для функции:
#
# ```python
# loss(x) = (x - 4)² + 1
# ```
#
# производная:
#
# ```python
# loss'(x) = 2(x - 4)
# ```

# %%
# TODO: напишите функцию loss_derivative(x)

# TODO: создайте список points

# TODO: посчитайте derivative_values

# TODO: создайте DataFrame со столбцами x, loss(x), loss'(x)

# TODO: покажите таблицу

# %% [markdown]
# ## Ячейка 5. TODO: проанализируйте рост и убывание

# %%
# TODO: создайте пустой список analysis

# TODO: для каждой точки из points посчитайте derivative

# TODO: если derivative < 0, статус = loss убывает

# TODO: если derivative > 0, статус = loss растёт

# TODO: если derivative == 0, статус = минимум

# TODO: добавьте словарь в analysis

# TODO: выведите analysis

# TODO: assert

# %% [markdown]
# ## Ячейка 6. TODO: сделайте простую оптимизацию

# %%
# TODO: задайте x_current далеко от минимума, например -2

# TODO: задайте learning_rate = 0.2

# TODO: задайте steps = 20

# TODO: создайте пустой список history

# TODO: в цикле сохраните step, x, loss, derivative

# TODO: обновите x_current по формуле:
# x_current = x_current - learning_rate * derivative

# TODO: выведите финальное x и финальный loss

# TODO: assert abs(x_current - 4) < 0.3

# %% [markdown]
# ## Ячейка 7. TODO: создайте таблицу шагов оптимизации

# %%
# TODO: создайте history_df = pd.DataFrame(history)

# TODO: покажите первые 10 строк

# TODO: assert len(history_df) == steps

# %% [markdown]
# ## Ячейка 8. TODO: постройте график движения к минимуму

# %%
# TODO: создайте x и loss для графика функции

# TODO: постройте график функции loss

# TODO: добавьте точки из history_df

# TODO: отметьте истинный минимум x=4, y=1

# TODO: добавьте legend и grid

# TODO: show()

# TODO: assert history_df["loss"].iloc[-1] < history_df["loss"].iloc[0]

# %% [markdown]
# ## Ячейка 9. TODO: создайте итоговый отчёт проекта

# %%
# TODO: создайте словарь project_report

# В словаре должны быть:
# project_name
# start_x
# final_x
# start_loss
# final_loss
# steps
# minimum_x
# minimum_loss

# TODO: выведите словарь через for

# TODO: assert final_loss < start_loss

# %% [markdown]
# ## Ячейка 10. TODO: сделайте выводы по блоку

# %%
# TODO: создайте список summary из 6 выводов

# TODO: выведите выводы через for

# TODO: assert len(summary) == 6

# %% [markdown]
# # Итог TODO-задания
#
# Покажите преподавателю:
#
# - функцию ошибки;
# - график функции;
# - производную;
# - таблицу производных;
# - анализ роста и убывания;
# - шаги оптимизации;
# - график движения к минимуму;
# - итоговый отчёт;
# - выводы по блоку.
#
# ## GitHub
#
# ```bash
# git add .
# git commit -m "feat: complete math informatics mini project"
# git push -u origin feature/block3-lesson10-math-mini-project
# ```
